# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/M-Talha-Farooqi/Machine-Learning-CourseWork/blob/main/Assignments/Assignment-2/assignment_2.ipynb)

# %% [markdown]
# # **Assignment 2: Matplotlib and Seaborn Libraries**
#
# You need to write the Python code that show all important functions of Matplotlib and Seaborn?

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_points = np.array([0, 6])
y_points = np.array([0, 250])

plt.plot(x_points , y_points)
plt.show()

# %%
# Plot graph with Two Points (marker) without Line
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
# Line Plot with Multiple Points
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Line Plot with Markers

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
# Line Plot with Star Markers
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
# Red Dotted Line Plot with Circle Markers
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
# Line Plot with Large Blue Circle Markers
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
# Line Plot with Large Red-Bordered Circle Markers
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
# Line Plot with Large Red-Filled Circle Markers [Marker face Color (mfc)]
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
# Line Plot with Large Red Markers (Border and Fill) => both mec and mfc
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %%
# Line Plot with Large Custom- (HEXADECIMAL) Markers
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
# line Style : Dotted Line Plot
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
# Line Style: Solid Line Style
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'solid')
plt.show()

# %%
# Line Style: Dashed Line Style
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
# Line Style: Dashdot Line Style
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dashdot')
plt.show()

# %%
# Line Style: No Line Style (Markers Only)
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'None', marker='o') # Added marker to make points visible
plt.show()

# %%
# Line width: Line Plot with Custom Line Width
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '12.8')
plt.show()

# %%
# Sine Wave Plot using np.linspace => returns 100 number from 0 - 10 having equal differnce from each other
x = np.linspace(0, 10, 100)
sineOfX = np.sin(x)

plt.plot(x, sineOfX)
plt.show()

# %%
# Cosine Wave Plot using np.linspace => returns 100 number from 0 - 10 having equal differnce from each other
x = np.linspace(0, 10, 100)
cosOfX = np.cos(x)

plt.plot(x, cosOfX)
plt.show()

# %%
# Parabolic Plot using np.linspace()
x = np.linspace(-10, 10, 20)
y = x**2

print(x)
print(y)

plt.plot(x, y)
plt.show()
# Out:
# [-10.          -8.94736842  -7.89473684  -6.84210526  -5.78947368
#   -4.73684211  -3.68421053  -2.63157895  -1.57894737  -0.52631579
#    0.52631579   1.57894737   2.63157895   3.68421053   4.73684211
#    5.78947368   6.84210526   7.89473684   8.94736842  10.        ]
# [100.          80.05540166  62.32686981  46.81440443  33.51800554
#   22.43767313  13.5734072    6.92520776   2.49307479   0.27700831
#    0.27700831   2.49307479   6.92520776  13.5734072   22.43767313
#   33.51800554  46.81440443  62.32686981  80.05540166 100.        ]

# %%
# Multiple Line Plots
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
# Multiple Line Plots with X and Y Arrays
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
# Sports Watch Data Plot using "LABELS" & "TITLE"
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
# Sports Watch Data Plot with Custom Fonts
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.show()

# %%
# Sports Watch Data Plot with Grid
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.grid()

plt.show()

# %%
# Sports Watch Data Plot with X-axis Grid
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.grid(axis='x')

plt.show()

# %%
# Sports Watch Data Plot with Y-axis Grid
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.grid(axis='y')

plt.show()

# %%
# Sports Watch Data Plot with Custom Grid
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
# Multiple Plots (Subplots)
# plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

# plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
# Multiple Plots (Subplots - Vertical)
# plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

# plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
# Six Subplots
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
# Subplots with Titles and Super Title
# plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

# plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
# Scatter Plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
# Compare Plots: Scatter Plot for Two Days of Car Data
# day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

# day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
# Scatter Plot with Individual Colorsfor each dot correspondingly
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)
plt.show()

# %%
# Scatter Plot with Colormap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 50, 55, 60, 70, 80, 90, 100, 110])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.show()

# %%
# Scatter Plot with 'PuRd' Colormap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 50, 55, 60, 70, 80, 90, 100, 110]) # Ensuring 13 elements

plt.scatter(x, y, c=colors, cmap='PuRd')
plt.colorbar()
plt.show()

# %%
# Scatter Plot with 'Greens' Colormap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 50, 55, 60, 70, 80, 90, 100, 110]) # Ensuring 13 elements

plt.scatter(x, y, c=colors, cmap='Greens')
plt.colorbar()
plt.show()

# %%
# Scatter Plot with 'Spectral' Colormap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 50, 55, 60, 70, 80, 90, 100, 110]) # Ensuring 13 elements

plt.scatter(x, y, c=colors, cmap='Spectral')
plt.colorbar()
plt.show()

# %%
# Scatter Plot with Varying Marker Sizes
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)
plt.show()

# %%
# Scatter Plot with Varying Marker Sizes and Transparency using alpha argument
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)
plt.show()

# %%
# Random Scatter Plot with Colormap, Varying Sizes and Transparency
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %%
# Bar Chart
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y)
plt.show()

# %%
# Horizontal bar Chart
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
# Bar chart with Custom color (pink)
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
# Bar chart with Custom color (green)
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
# Bar chart with custom width
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
# Horizontal Bar chart with custom width
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %%
# Histogram from random normal data
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
# Pie Chart without labels
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
# Pie Chart with labels
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
# Pie Chart with custom start angle
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
# Pie Chart with custom start angle and percentages
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90, autopct = '%0.2f%%')
plt.show()

# %%
# Pie Chart with custom start angle, percentages, and explode effect
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, startangle = 90, autopct = '%0.2f%%', explode = myexplode)
plt.show()

# %%
# Pie Chart with custom start angle, percentages, explode effect, shadow, legend, and title
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, startangle = 90, autopct = '%0.2f%%', explode = myexplode, shadow = True)
plt.legend(title = "Four Fruits:", loc="center left", bbox_to_anchor=(1.2, 0, 1, 1))
plt.title("List of Fruits")
plt.show()

# %%
# Create an empty figure
fig = plt.figure()
print(type(fig))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
# Create an empty figure
fig = plt.figure()
print(type(fig))

# Give the figure a title
fig.suptitle("Empty figure")
plt.show()
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
# Create a figure with a 2x2 grid of subplots
fig = plt.figure()

# Generate a grid of 2x2 subplots and get axes object for 1st location
ax1 = fig.add_subplot(2,2,1)
ax1.set_title('First Location')

# Get the axes object for subplot at 2nd location
ax2 = fig.add_subplot(2,2,2)
ax2.set_title('Second Location')

# Get the axes object for subplot at 3rd location
ax3 = fig.add_subplot(2,2,3)
ax3.set_xlabel('Third Location')

# Get the axes object for subplot at 4th location
ax4 = fig.add_subplot(2,2,4)
ax4.set_xlabel('Fourth Location')

# Display
plt.show()

# %%
# Plot data using the plot() method of the axes object
# Simple XY plot
# Generate data for plots
x = [1, 2, 3, 4, 5]
y = x

# Get an empty figure
fig1 = plt.figure()

# Get the axes instance at 1st location in 1x1 grid
ax = fig1.add_subplot(1,1,1)

# Generate the plot
ax.plot(x, y)

# Set labels for x and y axis
ax.set_xlabel('X--->')
ax.set_ylabel('Y--->')

# Set title for the plot
ax.set_title('Simple XY plot')

# Display the figure
plt.show()

# %%
# Multiple subplots in the same figure
# Function to get the square of each element in the list
def list_square(a_list):
    return [element**2 for element in a_list]

# Multiple subplots in same figure
fig3 = plt.figure()
x = [1, 2, 3, 4, 5]
y = x
z = list_square(x)

# Divide the figure into 1 row 2 column grid and get the
# axes object for the first column
ax1 = fig3.add_subplot(1,2,1)

# plot y = x on axes instance 1
ax1.plot(x, y)

# set x and y axis labels
ax1.set_xlabel('X------>')
ax1.set_ylabel('Y------>')
ax1.set_title('Y=x plot')

# Get second axes instance in the second column of the 1x2 grid
ax2 = fig3.add_subplot(1,2,2)

# plot z = x^2
ax2.plot(x, z)
ax2.set_xlabel('X------>')
ax2.set_ylabel('Z=x^2------>')
ax2.set_title('Z=x^2 plot')

# Generate the title for the Figure. Note that this is different then the title for individual plots
fig3.suptitle("Two plots in a figure")
plt.show()

# %%
# Creating Histogram through Object Oriented Approach

# Bar chart of languages spoken by people
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
languages = ['English','French','Spanish','Latin','German']
people = [100, 50, 150, 40, 70]
ax.bar(languages, people)
plt.xlabel('LANGUAGES')
plt.ylabel('NUMBER OF PEOPLE')
plt.show()

# %%
# Creating Pie chart through Object Oriented Approach
fig1 = plt.figure()
ax = fig1.add_axes([0,0,1,1])
languages = ['English', 'French', 'Spanish', 'Latin', 'German']
people = [100, 50, 150, 40, 70]
ax.pie(people, labels=languages, autopct='%1.1f%%')
plt.show()

# %%
# Creating Scatter chart through Object Oriented Approach
x = np.linspace(0,10,30)
y = np.sin(x)
z = np.cos(x)
fig2 = plt.figure()
ax = fig2.add_axes([0,0,1,1])
ax.scatter(x,y,color='g')
ax.scatter(x,z,color='b')
plt.show()

# %%
# Matplotlib California housing dataset plotting
import pandas as pd

# Read the csv file into a pandas dataframe
# A dataframe is basically a table of data.
Dataset_URL = "https://raw.githubusercontent.com/M-Talha-Farooqi/Machine-Learning-CourseWork/refs/heads/main/DataSets/Housing.csv"
df_housing = pd.read_csv(Dataset_URL)

# Get figure object and an array of axes objects
fig, arr_ax = plt.subplots(2, 2)

# Histogram - median_house_value
arr_ax[0,0].hist(df_housing['median_house_value'])
arr_ax[0,0].set_title('median_house_value')

# Histogram - median_income
arr_ax[0,1].hist(df_housing['median_income'])
arr_ax[0,1].set_title('median_income')

# Scatter - population vs total_rooms
arr_ax[1,0].scatter(df_housing['population'], df_housing['total_rooms'])
arr_ax[1,0].set_xlabel('population')
arr_ax[1,0].set_ylabel('total_rooms')

# scatter - median_income vs median_house_value
arr_ax[1,1].scatter(df_housing['median_income'], df_housing['median_house_value'])
arr_ax[1,1].set_xlabel('median_income')
arr_ax[1,1].set_ylabel('median_house_value')

plt.show()

print('DONE : Matplotlib california housing dataset plotting')
# Out:
# DONE : Matplotlib california housing dataset plotting

# %% [markdown]
# # **SeaBorn**
#
# **Seaborn:** Seaborn is a Data Visualization library that uses Matplotlib underneath to plot graphs. It is easier to plot complex graphs with less code as compared to Matplotlib. Let's learn it.
#
# Seaborn has *built-in datasets* for us. One of the datasets is the Restaurant Customer Bill and Tips Dataset. Customer visit the rstaurant for Lunch or Dinner. Dataset records the amount of total bill along with the amount given to waiters as tip. Dataset also gives other details about customer such as sex smoker or not, day of the week, time either Lunch or dinner and size as number of people visited together. Let's import the dataset.

# %%
# Let's Import Seaborn as sns and all other needed libaries
import seaborn as sns

# Tips Dataset has been imported as DataFrame
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# Setting a theme for the plots and visualizing the data
sns.set_theme()
# Visualize Data
sns.relplot(data=tips, x='total_bill',y='tip',col='time',hue='smoker',style='smoker',size='size')

# %% [markdown]
# # **Built in IRIS Dataset**

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# Scatter plot of sepal_length vs petal_length by species
sns.scatterplot(x='sepal_length',y='petal_length',hue='species',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # **Built in Titanic Dataset**

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# Count plot of passenger class on Titanic
sns.countplot(x='class',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# Count plot of survival on Titanic
sns.countplot(x='survived', data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# Bar plot of survival rate by sex and class
sns.barplot(x='sex',y='survived',hue='class',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %% [markdown]
# # **Boston Housing Dataset**

# %%
# Boston house price dataset

Dataset_URL = "https://raw.githubusercontent.com/M-Talha-Farooqi/Machine-Learning-CourseWork/refs/heads/main/DataSets/Boston%20Housing%20Data.csv"
boston = pd.read_csv(Dataset_URL)

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
print("Columns in your dataset:", boston.columns.tolist())
# Out:
# Columns in your dataset: ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat', 'medv']

# %%
if 'medv' in boston.columns:
    boston.rename(columns={'medv': 'PRICE'}, inplace=True)
    print("Renamed 'medv' to 'PRICE'.")
elif 'PRICE' not in boston.columns:
    print("Warning: Neither 'medv' nor 'PRICE' column found. Please check your CSV")
# Out:
# Renamed 'medv' to 'PRICE'.

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   5.33   36.2

# %%
boston.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  PRICE
# 501  391.99   9.67   22.4
# 502  396.90   9.08   20.6
# 503  396.90   5.64   23.9
# 504  393.45   6.48   22.0
# 505  396.90   7.88   11.9

# %%
# Distribution plot of the house prices
sns.displot(boston['PRICE'])

# %% [markdown]
# # **The END**
